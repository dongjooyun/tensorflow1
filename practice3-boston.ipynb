# %% [markdown]
# # 보스턴 집값 예측(여기까지 회귀 모델)
# - github csv url: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv

# %% [markdown]
# ### 0. Tensorflow & Pandas 라이브러리 사용

# %%
import tensorflow as tf
import pandas as pd

# %% [markdown]
# ### 1-1. 과거의 축적된 데이터 준비

# %%
Bt_fileroute = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
Boston = pd.read_csv(Bt_fileroute)
print(Boston.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# ### 1-2. 독립변수, 종속변수 분리

# %%
inde_var = Boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
de_var = Boston[['medv']]
print(inde_var.shape, de_var.shape)
# Out:
# (506, 13) (506, 1)

# %% [markdown]
# ### 2. 모델 구조 생성

# %%
X = tf.keras.layers.Input(shape=[13]) # 13: 독립변수 개수
Y = tf.keras.layers.Dense(1)(X) # 1: 종속변수 개수
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %% [markdown]
# ### 3-1.데이터로 모델 학습(FIT)
# 학습이 잘 될수록 0에 가까워짐 | 원하는 loss값으로 떨어질 때까지 epoch 더 하기

# %%
model.fit(inde_var, de_var, epochs=10000, verbose=0)

# %% [markdown]
# ### 3-2. 모델의 loss값 확인

# %%
model.fit(inde_var, de_var, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.8735
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.9007
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.9414
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.1110
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.0295
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.7911
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.8930
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.1793
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.7690
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.2172

# %% [markdown]
# ### 4-1. 모델 이용하여 예측

# %%
print(model.predict(inde_var[5:10]))
# Out:
# [[25.606537]
#  [22.197268]
#  [19.231606]
#  [11.092228]
#  [18.572712]]

# %% [markdown]
# ### 4-2. 실제값 & 예측값 비교
# epochs 값 더 늘리기 😓

# %%
print(de_var[5:10])
# Out:
#    medv
# 5  28.7
# 6  22.9
# 7  27.1
# 8  16.5
# 9  18.9

# %% [markdown]
# ### 4-3. 모델의 수식 확인

# %%
print(model.get_weights())
# Out:
# [array([[-0.09125994],
#        [ 0.04864686],
#        [-0.01799685],
#        [ 2.6341548 ],
#        [-2.5633721 ],
#        [ 5.232558  ],
#        [-0.00976473],
#        [-1.0741862 ],
#        [ 0.20187639],
#        [-0.01064589],
#        [-0.5280908 ],
#        [ 0.01335181],
#        [-0.4625147 ]], dtype=float32), array([9.042839], dtype=float32)]
